# %% [markdown]
# <a href="https://www.kaggle.com/code/pogscafe/instantmesh?scriptVersionId=182294627" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # InstantMesh
#
# InstantMesh transforms 2D images into 3D models.
#
# How-to video:
# <a href="https://youtu.be/1djup5Z7n6I"><img src="https://i3.ytimg.com/vi/1djup5Z7n6I/maxresdefault.jpg" width=200) /></a>
#
# This notebook on GitHub: https://github.com/wandaweb/InstantMesh-Kaggle
#
# InstantMesh on GitHub: https://github.com/TencentARC/InstantMesh
#
# ---
# Connect with us for updates - https://pogscafe.bio.link

# %% [markdown]
# ## Installation

# %%
# Install InstantMesh
# %cd /kaggle/working

# !git clone https://github.com/wandaweb/InstantMesh/
# !pip install triton
# %cd InstantMesh
# !pip install -r requirements.txt

# Install FileBrowser
# !wget https://github.com/filebrowser/filebrowser/releases/download/v2.27.0/linux-amd64-filebrowser.tar.gz
# !tar xvfz linux-amd64-filebrowser.tar.gz
# !chmod a+x filebrowser
# !rm /kaggle/working/config.json
# !/kaggle/working/InstantMesh/filebrowser config init 
# !/kaggle/working/InstantMesh/filebrowser config set --auth.method=noauth > /dev/null
# !/kaggle/working/InstantMesh/filebrowser config set --branding.theme=dark > /dev/null
# !/kaggle/working/InstantMesh/filebrowser users add admin admin > /dev/null
# !pip install tensorflow[and-cuda]
# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ## Run the WebUI
#
# Wait for the line "Running on local URL:  http://0.0.0.0:7860 " and click the link ending with .pinggy.link between the smiling emojis.
# It can take about a minute for the line to appear.

# %%
# %cd /kaggle/working/InstantMesh
       
from multiprocessing import Process
import sys
import time

open('log.txt', 'w').close()

def run_app():
    # !python app.py & ssh -o StrictHostKeyChecking=no -p 80 -R0:localhost:7860 a.pinggy.io > log.txt
    
def print_url():
    print("waiting for output")
    time.sleep(2)
    sys.stdout.flush()
    
    found = False
    with open('log.txt', 'r') as file:
        end_word = '.pinggy.link'
        for line in file:
            #print(line)
            start_index = line.find("http:")
            if start_index != -1:
                end_index = line.find(end_word, start_index)
                if end_index != -1:
                    print("😁 😁 😁")
                    print("URL: " + line[start_index:end_index + len(end_word)])
                    print("😁 😁 😁")
                    found = True
    if not found:
        print_url()
    else:
        with open('log.txt', 'r') as file:
            for line in file:
                print(line)
    
p_app = Process(target=run_app)
p_url = Process(target=print_url)
p_app.start()
p_url.start()
p_app.join()
p_url.join()

# %% [markdown]
# ## Run from the command line

# %%
# !python run.py configs/instant-mesh-base.yaml /kaggle/working/InstantMesh/examples/sword.png --save_video --export_texmap

# %% [markdown]
# ---
# # File Browser

# %% [markdown]
# ## Start FileBrowser
#
# * Follow the .pinggy.link link to interact with FileBrowser.
# * Outputs are in the folder working -> InstantMesh -> outputs
# * If the app starts with a login screen, the username and password are both "admin"

# %%
# %cd /kaggle/working/

# !chmod a+x /kaggle/working/InstantMesh/filebrowser
# !/kaggle/working/InstantMesh/filebrowser config set --auth.method=noauth > /dev/null
        
from multiprocessing import Process
import sys
import time

open('log.txt', 'w').close()

def run_app():
    # !/kaggle/working/InstantMesh/filebrowser -c "/kaggle/working/config.json" & ssh -o StrictHostKeyChecking=no -p 80 -R0:localhost:8080 a.pinggy.io > log.txt 
    
def print_url():
    print("waiting for output")
    time.sleep(2)
    sys.stdout.flush()
    
    found = False
    with open('log.txt', 'r') as file:
        end_word = '.pinggy.link'
        for line in file:
            #print(line)
            start_index = line.find("http:")
            if start_index != -1:
                end_index = line.find(end_word, start_index)
                if end_index != -1:
                    print("😁 😁 😁")
                    print("URL: " + line[start_index:end_index + len(end_word)])
                    print("😁 😁 😁")
                    found = True
    if not found:
        print_url()
    else:
        with open('log.txt', 'r') as file:
            for line in file:
                print(line)
    
p_app = Process(target=run_app)
p_url = Process(target=print_url)
p_app.start()
p_url.start()
p_app.join()
p_url.join()

# %%
# !mv /kaggle/working/InstantMesh /kaggle/working/InstantMesh_new

# %%
# %cd /kaggle/working
# !git clone https://github.com/WandaWeb/InstantMesh

# %%
# !mkdir /kaggle/working/tc
# %cd /kaggle/working/tc
# !git clone https://github.com/TencentARC/InstantMesh
